# %% [markdown]
# <a href="https://colab.research.google.com/github/iabdullahW/23122206_M.Abdullah/blob/main/M_Abdullah_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
payment_done = True
customer = "Ali"
amount = 25000

if payment_done:
    print(f"Receipt generated for {customer}: PKR {amount}")
else:
    print("Payment not done. Please complete payment first.")
# Out:
# Receipt generated for Ali: PKR 25000
