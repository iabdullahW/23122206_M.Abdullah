# %% [markdown]
# <a href="https://colab.research.google.com/github/iabdullahW/23122206_M.Abdullah/blob/main/M_Abdullah_Lab2ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google import genai
from google.colab import userdata

# Retrieve API Key from Colab Secrets
api_key = userdata.get("GEMINI_API_KEY")

# Initialize Client
client = genai.Client(api_key=api_key)

print("Gemini Chatbot (type 'exit' to quit)\n")
while True:
    user_input = input("You: ")

    # Exit condition
    if user_input.lower() in ["exit", "quit", "bye"]:
        print("Chatbot: Goodbye 👋")
        break

    # Send input using the latest model
    response = client.models.generate_content(
        model="gemini-3.6-flash",
        contents=user_input,
    )

    # Print response
    print("Chatbot:", response.text)
# Out:
# Gemini Chatbot (type 'exit' to quit)
#
# You: babar azam
# Chatbot: **Babar Azam** (born October 15, 1994, in Lahore, Pakistan) is a Pakistani international cricketer and former captain of the Pakistan national cricket team across all formats. He is widely considered one of the top modern-day batsmen in world cricket, renowned for his elegant technique and exceptional consistency.
#
# ---
#
# ### **Key Career Highlights & Achievements**
#
# * **World Rankings:**
#   * Held the **No. 1 ranking for ODI batsmen** for over 1,000 consecutive days (2021–2023).
#   * Has consistently been ranked among the top batsmen across all three formats (Tests, ODIs, and T20Is) simultaneously.
# * **ICC Awards:**
#   * **Sir Garfield Sobers Trophy** (ICC Men's Cricketer of the Year): 2022
#   * **ICC Men's ODI Cricketer of the Year:** 2021, 2022
# * **National Honors:** Awarded the **Sitara-i-Imtiaz** in 2023, Pakistan’s third-highest civilian award, becoming the youngest cricketer to receive it.
# ...
