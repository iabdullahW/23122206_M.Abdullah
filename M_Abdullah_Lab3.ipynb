# %% [markdown]
# <a href="https://colab.research.google.com/github/iabdullahW/23122206_M.Abdullah/blob/main/M_Abdullah_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai
from google import genai

client = genai.Client(api_key="GEMINI_API_KEY")


MODEL = "models/gemini-3.5-flash"


def travel_agent(user_input):

    prompt = f"""
You are a professional travel agent for Pakistan tourism.

Provide a well-structured travel plan with clear headings:

1. Destination Overview
2. Budget Travel Options (Bus, Train, Flight with approx cost in PKR)
3. Places to Visit (specific locations)
4. Food Suggestions (local dishes)
5. Money-Saving Tips

Make response detailed but easy for students.

User request: {user_input}

Travel Plan:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text



print("Gemini Travel Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye ")
        break

    try:
        reply = travel_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# Requirement already satisfied: google-genai in /usr/local/lib/python3.13/dist-packages (2.22.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (4.14.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.56.0 in /usr/local/lib/python3.13/dist-packages (from google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.57.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.5 in /usr/local/lib/python3.13/dist-packages (from google-genai) (2.13.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.13/dist-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (4.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.13/dist-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.13/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.19)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (50.0.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.1.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.13/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.6.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (3.0)
# Gemini Travel Agent Started (type 'exit' to stop)
#
#
# Agent:
#  Hello! I am your dedicated Pakistan Tourism Travel Agent.
#
# Since you gave a warm "hi," I have designed the ultimate student-friendly, budget-conscious travel plan to **Hunza Valley (Gilgit-Baltistan)**. Hunza is the crown jewel of Pakistan’s tourism—safe, breathtakingly beautiful, culturally rich, and highly affordable if planned right.
#
# Here is your complete, easy-to-follow travel plan!
#
# ---
#
# ### 1. Destination Overview
# **Hunza Valley** is a mountainous valley in the northern part of Gilgit-Baltistan. Known for its soaring peaks (like Rakaposhi and Ladyfinger), turquoise lakes, and incredibly hospitable people, it is a paradise for students.
# * **Best Time to Visit:** May to October (for pleasant weather) or October to November (for stunning autumn colors).
# * **Vibe:** Adventure, culture, hiking, and peaceful nature.
#
# ---
#
# ### 2. Budget Travel Options (From Islamabad as the starting hub)
# *To get to Islamabad first, students can take the **Tezgam or Green Line Train (Economy Class)** from Lahore/Karachi, costing around **PKR 2,000 to PKR 4,500**.*
#
# From Islamabad to Hunza:
#
# * **By Bus (Most Popular for Students):**
#   * **Service:** NATCO (National Bus Service) or Faisal Movers.
#   * **Route:** Islamabad to Gilgit/Aliabad (Hunza).
#   * **Approx. Cost:** **PKR 3,500 – PKR 4,500** (one-way).
#   * **Travel Time:** 14–16 hours via the scenic Karakoram Highway or Babusar Top (in summer).
#
# * **By Flight (Fast but Weather Dependent):**
#   * **Service:** PIA (Pakistan International Airlines) from Islamabad to Gilgit Airport.
#   * **Approx. Cost:** **PKR 16,000 – PKR 25,000** (one-way).
#   * *Note: Flights often get cancelled due to weather, so buses are more reliable for tight student schedules.*
#
# * **Local Commute (Within Hunza):**
#   * Use local shared public vans (Hiace) running between Aliabad, Karimabad, and Ghalapan.
#   * **Approx. Cost:** **PKR 150 – PKR 400** per ride.
#
# ---
#
# ### 3. Places to Visit (Budget-Friendly Locations)
# You don't need expensive tour guides to see these stunning spots:
#
# * **Altit and Baltit Forts (Karimabad):** Hundreds of years old, these Tibetan-style forts offer panoramic views of the valley. *(Student ticket discounts are available with a valid student ID).*
# * **Attabad Lake:** A stunning, bright-blue lake formed after a landslide. You can enjoy a budget-friendly group boat ride here for about **PKR 500 - 1,000 per person**.
# * **Passu Cones & Suspension Bridge:** Capture photos of the iconic pointed mountain peaks. Walk across the thrilling, rope-and-plank Passu suspension bridge (completely free to visit!).
# * **Eagle’s Nest (Duiker):** The highest viewpoint in Hunza. Hike up here in the evening to watch a breathtaking sunset over 11 peaks of the Karakoram range.
# * **Khunjerab Pass (Pak-China Border):** The world’s highest paved border crossing. You can pool money with other travelers to rent a shared taxi/Hiace from Karimabad to the border.
#
# ---
#
# ### 4. Food Suggestions (Must-Try Local Dishes)
# Hunza’s food is organic, healthy, and very affordable at local dhabas:
#
# * **Chapshuro (The Hunza Pizza):** A crispy bread stuffed with seasoned minced beef or yak meat, onions, and local spices.
#   * **Approx Cost:** **PKR 250 – PKR 400** (Easily fills one person).
# * **Dowodo:** A warm, homemade noodle soup cooked with wheat flour noodles and meat. Perfect for chilly Hunza evenings.
#   * **Approx Cost:** **PKR 200 – PKR 350**.
# * **Tumuro Tea:** A local herbal tea made from wild thyme gathered from the mountains. Great for digestion and keeping warm.
#   * **Approx Cost:** **PKR 50 – PKR 100** per cup.
# * **Fresh/Dried Apricots & Walnuts:** You will find apricot trees everywhere. Locals often gift them, or you can buy a bag of dried fruits very cheaply.
#
# ---
#
# ### 5. Money-Saving Tips for Students
#
# 1. **Travel in Groups of 4 or 5:** This allows you to split the cost of hotel rooms (triple or quad sharing) and local jeep/taxi rentals.
# 2. **Carry Your Student ID Card:** Showing your university ID card gets you up to **50% off** entry tickets at national heritage sites, forts, and some public transport.
# 3. **Stay in Local Homestays/Hostels:** Instead of luxury hotels, stay in backpacker hostels in Karimabad or local homestays. You can easily find a clean room for **PKR 2,000 to PKR 3,500 per night** if you negotiate.
# 4. **Avoid Peak Season Weeks:** Avoid traveling during national holidays (like Eid or Independence Day) when hotel prices double. Travel during early June or September.
# 5. **Eat Where the Locals Eat:** Avoid fancy tourist restaurants on the main highways. Eat at local bazaars in Aliabad where food is fresh, delicious, and half the price.
#
# Safe travels! Let me know if you would like me to calculate a total estimated budget for your specific group size or trip duration.

# %%
# !pip install -U google-genai
from google import genai

client = genai.Client(api_key="GEMINI_API_KEY")


MODEL = "models/gemini-3.6-flash"


def study_agent(user_input):

    prompt = f"""
You are a professional agent of smart Ai study .

Provide a well structured plan for studying:

1. Overview of Study plan.
2. Study Materials.
3. Study Tips.
4. Study Resources.
5. Study Practice.

Make response detailed but easy for students.

User request: {user_input}

Study Plan:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text



print("Gemini Ai Study Helper (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye ")
        break

    try:
        reply = study_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# Requirement already satisfied: google-genai in /usr/local/lib/python3.13/dist-packages (2.22.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (4.14.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.56.0 in /usr/local/lib/python3.13/dist-packages (from google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.57.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.5 in /usr/local/lib/python3.13/dist-packages (from google-genai) (2.13.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.13/dist-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (4.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.13/dist-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.13/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.19)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (50.0.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.1.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.13/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.6.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (3.0)
# Gemini Ai Study Helper (type 'exit' to stop)
#
# You: ai
# Error: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# You: ai
#
# Agent:
#  Hello! I am your **Smart AI Study Agent**.
#
# Artificial Intelligence (AI) is one of the most exciting, fast-growing fields in the world. Whether you want to build the next ChatGPT, analyze complex data, or create smart applications, this structured study plan will guide you from a complete beginner to a confident AI practitioner.
#
# Here is your customized, highly-efficient **AI Study Plan**.
#
# ---
#
# ## 1. Overview of the Study Plan
# This is a **12-Week Roadmap** designed to take you from foundational mathematics and coding to building your own Deep Learning and Generative AI models.
#
# ```
# [ Weeks 1-3 ] ────► [ Weeks 4-6 ] ────► [ Weeks 7-9 ] ────► [ Weeks 10-12 ]
#  Foundations         Machine Learning     Deep Learning      Generative AI &
#  (Python & Math)       (Algorithms)     (Neural Networks)       Projects
# ```
#
# ### Phase 1: The Launchpad (Weeks 1-3)
# *   **Goal:** Master the tools of the trade.
# *   **Focus:** Python programming, essential mathematics (Linear Algebra, Calculus, Probability), and basic data manipulation.
#
# ### Phase 2: Machine Learning Core (Weeks 4-6)
# *   **Goal:** Understand how computers "learn" from data.
# *   **Focus:** Supervised learning (regression, classification), unsupervised learning (clustering), and the popular `Scikit-Learn` library.
#
# ### Phase 3: Deep Learning & Neural Networks (Weeks 7-9)
# *   **Goal:** Mimic the human brain to process complex data (images, text).
# *   **Focus:** Artificial Neural Networks (ANNs), Convolutional Neural Networks (CNNs for images), and Deep Learning frameworks (`PyTorch` or `TensorFlow`).
#
# ### Phase 4: Modern AI & Deployment (Weeks 10-12)
# *   **Goal:** Step into the modern era of Generative AI.
# *   **Focus:** Natural Language Processing (NLP), Large Language Models (LLMs), Hugging Face, and deploying a real AI application.
#
# ---
#
# ## 2. Study Materials
# To avoid overwhelm, focus on these high-yield, top-tier materials:
#
# *   **Essential Books:**
#     *   *For Beginners:* "Python Crash Course" by Eric Matthes (great for getting Python down fast).
#     *   *The AI Bible:* "Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow" by Aurélien Géron (highly readable and practical).
# *   **Video Courses (Free & Premium):**
#     *   *Machine Learning Specialization* (Coursera) by Andrew Ng (The absolute best starting point).
#     *   *Fast.ai* – "Practical Deep Learning for Coders" (Free, hands-on, and code-first approach).
# *   **Quick Reference Cheat Sheets:**
#     *   [Stanford Machine Learning Cheat Sheets](https://vip.stanford.edu/wiki/cs229/) (Great for quick math/algorithm review).
#     *   Python for Data Science Cheat Sheet (by Datacamp).
#
# ---
#
# ## 3. Smart Study Tips
# AI can be mathematically heavy and conceptually abstract. Use these cognitive science-backed tips to study smarter, not harder:
#
# *   **Tip 1: The "Code-First" Rule (No Passive Watching):** Never just watch a lecture video. For every 15 minutes of video you watch, spend 30 minutes writing, breaking, and fixing the code yourself.
# *   **Tip 2: Use the Feynman Technique:** Try to explain how an AI concept (like *Gradient Descent* or *Overfitting*) works to a 10-year-old. If you can’t simplify it, you don't understand it yet.
# *   **Tip 3: Don't Get Stuck in "Math Purgatory":** You do not need a Ph.D. in math to start. Learn the *intuition* behind the math (e.g., what a matrix multiplication does conceptually) and let the Python libraries do the heavy calculation.
# *   **Tip 4: Build a "Digital Garden":** Keep a Jupyter Notebook or Notion page where you write down short, visual summaries of algorithms you learn.
#
# ---
#
# ## 4. Study Resources & Tools
# Set up your AI developer environment and join these learning communities:
#
# *   **Coding Environments:**
#     *   **Google Colab:** Free, runs in your browser, and gives you free access to powerful GPUs (crucial for Deep Learning). No installation required!
#     *   **Jupyter Notebook:** The standard offline tool for data scientists.
# *   **Data & Project Sources:**
#     *   **Kaggle:** The ultimate playground for AI. Access thousands of free datasets and enter beginner-friendly competitions.
# *   **Interactive Visualizations:**
#     *   **TensorFlow Playground:** An interactive web game where you can watch a neural network learn in real-time.
# *   **Communities for Help:**
#     *   **Discord/Reddit:** Join `r/learnmachinelearning` and the Hugging Face Discord to ask questions when you get stuck.
#
# ---
#
# ## 5. Study Practice & Hands-on Projects
# You learn AI by building it. Here are three milestone projects to complete during your 12-week journey:
#
# ### 🏠 Level 1: Beginner Project (Week 5)
# *   **Project:** House Price Predictor.
# *   **Task:** Use a dataset of house features (bedrooms, square footage) to predict their prices.
# *   **Skills practiced:** Linear Regression, Data Cleaning, Scikit-Learn.
#
# ### 🐱 Level 2: Intermediate Project (Week 9)
# *   **Project:** Cat vs. Dog Image Classifier.
# *   **Task:** Build a model that can look at a photo and tell you if it's a cat or a dog.
# *   **Skills practiced:** Convolutional Neural Networks (CNNs), PyTorch/TensorFlow, Image Preprocessing.
#
# ### 🤖 Level 3: Advanced/Modern Project (Week 12)
# *   **Project:** Custom AI Chatbot (using your own data).
# *   **Task:** Use a pre-trained Large Language Model (like LLaMA or GPT-4 API) and use **RAG** (Retrieval-Augmented Generation) to make it answer questions about a specific PDF or book.
# *   **Skills practiced:** Hugging Face, LLMs, LangChain, APIs.
#
# ---
#
# ### Your Next Step:
# Open **Google Colab**, write your first line of Python: `print("Hello, AI World!")`, and commit to just **30 minutes a day**. You've got this! If you need me to break down any specific topic in this plan, just ask.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1804/1444420040.py in <cell line: 0>()
#      40
#      41 while True:
# ---> 42     user = input("You: ")
#      43
#      44     if user.lower() == "exit":
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
